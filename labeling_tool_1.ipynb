# %%
import label_backend
from label_backend import *

# %%
display(initialize_widgets('data_to_label.sqdb','config/labeling_projects.cfg'))

# %%
sql_get('data_to_label.sqdb','SELECT * FROM to_label').head(20)
# Out:
#     id             case_id                                            content  \
# 0    1  5002700000lAvOoAAK  <h4>DL385p Gen8 - Controller Failure</h4><p>Co...
# 1    2  5002700000lavS9AAI  <h4>HP DL380 G7 - HDD failure - ACD</h4><p>HDD...
# 2    3  5002700000lAVOiAAO  <h4>DL380p Gen8 - Hard Drive Failure</h4><p>Ha...
# 3    4  5002700000laVOLAA2  <h4>DL360 Gen9 - High latency</h4><p>High Late...
# 4    5  5002700000lAVnxAAG  <h4>CB 25/07 to close case / HP ProLiant DL380...
# 5    6  5002700000lAVOdAAO   <h4>customer meeting</h4><p>customer meeting</p>
# 6    7  5002700000lavu3AAA  <h4>HP DL380 Gen9 8SFF CTO Server - PS failed<...
# 7    8  5002700000lAVUqAAO  <h4>DL380 G7 - Souci de Demarrage (suite au 53...
# 8    9  5002700000lAvt8AAC  <h4>DL360 Gen9 - Flashing Amber Health LED</h4...
# 9   10  5002700000lAvTyAAK  <h4>SC/6HR CTRep/7Hol/ProLiant/CZ232907XB:6421...
# 10  11  5002700000lAvOoAAK  <h4>DL385p Gen8 - Controller Failure</h4><p>Co...
# ...
